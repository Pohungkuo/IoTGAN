# %% [markdown]
# <a href="https://colab.research.google.com/github/Pohungkuo/IoTGAN/blob/master/IoTGAN_acc_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
# !pip install tensorboardX

# %%
# !python IoTmain_acctest.py --train-digit 5 --task-number 1
# Out:
# WARNING:tensorflow:From IoTmain_acctest.py:39: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# ...

# %%
# !rm -r IoTGAN_Acc_0122/3modes/digit-5/

# %%
# !tar -czvf 3modes.tar.gz ./IoTGAN_Acc_0122/3modes
# Out:
# ./IoTGAN_Acc_0122/3modes/
# ./IoTGAN_Acc_0122/3modes/digit-5/
# ./IoTGAN_Acc_0122/3modes/digit-5/Test-image-step-000200.png
# ./IoTGAN_Acc_0122/3modes/digit-5/2ndGAN-digit-step-001400.png
# ./IoTGAN_Acc_0122/3modes/digit-5/2ndGAN-digit-step-001000.png
# ./IoTGAN_Acc_0122/3modes/digit-5/GAN2-InputTrainArray-step-000400.png
# ./IoTGAN_Acc_0122/3modes/digit-5/GAN2-InputTrainArray-step-000200.png
# ./IoTGAN_Acc_0122/3modes/digit-5/2ndGAN-digit-step-000800.png
# ./IoTGAN_Acc_0122/3modes/digit-5/Test-image-step-001600.png
# ./IoTGAN_Acc_0122/3modes/digit-5/GAN2-InputTrainArray-step-000000.png
# ./IoTGAN_Acc_0122/3modes/digit-5/GAN2-InputTrainArray-step-000600.png
# ./IoTGAN_Acc_0122/3modes/digit-5/Test-image-step-001400.png
# ./IoTGAN_Acc_0122/3modes/digit-5/2ndGAN-digit-step-001800.png
# ./IoTGAN_Acc_0122/3modes/digit-5/2ndGAN-digit-step-001200.png
# ./IoTGAN_Acc_0122/3modes/digit-5/Test-image-step-001200.png
# ./IoTGAN_Acc_0122/3modes/digit-5/Test-image-step-002400.png
# ...
